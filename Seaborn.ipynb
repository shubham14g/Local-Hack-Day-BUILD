# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
'''np.random.seed(101)  
sns.set()'''
# Out:
# 'np.random.seed(101)  \nsns.set()'

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
 sns.jointplot(x='total_bill',y='tip',data=tips,kind='resid')

# %%
 sns.pairplot(tips,hue='sex',palette='Set1')

# %%
sns.kdeplot(tips['tip'],tips['total_bill'])

# %%
 sns.boxplot(data=tips,palette='rainbow')

# %%
 sns.violinplot(x="day", y="total_bill", data=tips,palette='Set1')

# %%
 sns.stripplot(x="day", y="total_bill", data=tips,jitter=0.2)

# %%
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True,hue='sex',palette='Set1',dodge=True)

# %%
sns.violinplot(x="tip", y="day", data=tips,palette='rainbow')             
sns.swarmplot(x="tip", y="day", data=tips,color='black',size=3)

# %%
sns.kdeplot(tips['tip'],tips['total_bill'],shade=True,cbar=True)

# %%
sns.heatmap(tips.corr(),annot=True)

# %%
 sns.heatmap(tips.corr(),cmap='coolwarm',annot=True)

# %%
flights=sns.load_dataset('flights')

# %%
pvflights=flights.pivot_table(values='passengers',index='month',columns='year') 
sns.heatmap(pvflights,linecolor='white',linewidth=1)

# %%
 sns.clustermap(pvflights,annot=True)

# %%
iris = sns.load_dataset('iris') 
g = sns.pairplot(iris)

# %%
g = sns.PairGrid(iris)      
g.map_diag(plt.hist)    
g.map_upper(plt.scatter)    
g.map_lower(plt.scatter)

# %%
sns.PairGrid(iris)

# %%
tips.head(30)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
 g = sns.FacetGrid(tips, col="time", row="smoker")

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='seismic',markers=['o','v'], scatter_kws={'s':100})

# %%
sns.set()
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',palette='seismic',height=8)

# %%
sns.countplot(x='sex',data=tips)     
sns.despine() 
sns.set_style('ticks')

# %%
sns.set_context('talk')     
sns.countplot(x='sex',data=tips,palette='seismic')
